# %% [markdown]
# # 2020117066 김재홍
# # 연습문제 6주차
#
# 1.	사용자로부터 임의의 수를 연속적으로 입력받도록 하시오. 이 수들에 대한 평균값, 최댓값, 최솟값을 반환하는 함수 mean_of_n(nums), max_of_n(nums), min_of_n(nums)을 구현하여 다음과 같이 출력하여라.
#
# ![image-2.png](attachment:image-2.png)

# %%
def mean_of_n(nums):
    sum_num = 0
    for i in nums:
        sum_num += i
    print('평균값은 {:.1f}'.format(sum_num/len(numbers)))

def max_of_n(nums):
    max_num = nums[0]
    for i in nums:
        if i > max_num:
            max_num = i
    print('최댓값은 {}'.format(max_num))

def min_of_n(nums):
    min_num = nums[0]
    for i in nums:
        if i < min_num:
            min_num = i
    print('최솟값은 {}'.format(min_num))

number = list(map(int,input("정수를 여러 개 입력하시오 : ").split()))
aver(number)
max_of_n(number)
min_of_n(number)
# Out:
# 정수를 여러 개 입력하시오 : 1 2 3 4 9 8 55
# 평균값은 11.7
# 최댓값은 55
# 최솟값은 1

# %% [markdown]
# 2.	직각삼각형의 빗변을 이루는 선분의 양 끝점을 나타내는 두 좌표 (x1, y1), (x2, y2)를 입력받아 직각삼각형의 면적을 구하는 프로그램을 작성하여라. 이때 4개의 좌표값을 입력으로 받아 직각삼각형의 면적을 반환하는 area(x1, y1,x2, y2) 함수를 구현하시오.단, x2>x1이고 y2>y1이다.
#
# ![image-3.png](attachment:image-3.png)

# %%
def tri_area(x1, y1, x2, y2):
        length = x2 - x1
        height = y2 - y1
        area = length * height / 2

        print("직각삼각형의 면적은 : {}".format(area))

x1 = int(input("x1 좌표를 입력하시오 :"))
y1 = int(input("y1 좌표를 입력하시오 :"))
x2 = int(input("x2 좌표를 입력하시오 :"))
y2 = int(input("y2 좌표를 입력하시오 :"))

tri_area(x1, y1, x2, y2)
# Out:
# x1 좌표를 입력하시오 :0
# y1 좌표를 입력하시오 :0
# x2 좌표를 입력하시오 :3
# y2 좌표를 입력하시오 :4
# 직각삼각형의 면적은 : 6.0

# %% [markdown]
# 3.	쉼표 단위로 구분된 정수를 임의의 수만큼 입력받은 후 이 숫자들을 오름차순으로 정렬하여 출력하시오.
# 힌트: split( ) 메소드를 사용한다.
#
# ![image-2.png](attachment:image-2.png)

# %%
nums = []
nums =  list(map(int,input("쉼표로 구분된 정수를 여러 개 입력하시오 : ").split(',')))
print("입력된 정수의 리스트 : {}".format(nums))
nums = str(sorted(nums))
print(nums)
#print("정렬된 정수의 리스트 : {}".format(' '.join(nums)))
# 어떻게 , 와 대괄호를 없애지...
# Out:
# 쉼표로 구분된 정수를 여러 개 입력하시오 : 1,3,2
# 입력된 정수의 리스트 : [1, 3, 2]
# [1, 2, 3]
# 정렬된 정수의 리스트 : [ 1 ,   2 ,   3 ]
